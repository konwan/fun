# %%
import urllib.request
import time 

# dns = "https://encrypted-tbn0.gstatic.com/"
dns = "http://universal-yoga.com/docs/images/"

des = "/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_"
# file = "images?q=tbn:ANd9GcQOoixz8xtFbPwDCRCLwuA1RcpPmIznIhPqlLk1vN9rUmvDPgo5"
file = "date_vinyasa_"

for i in range(1,121):
#     print("{}{}.jpg".format(des,i))
    src = "{}{}{}.gif".format(dns,file,i) 
    try:
#         res = src
        res = urllib.request.urlretrieve(src, "{}{}.gif".format(des,i))
        time.sleep(1) 
        #print(list(res)[1].__dict__)
        print(res)
    except:
        print("erro file {}".format(i))
# Out:
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_1.gif', <http.client.HTTPMessage object at 0x1104eb358>)
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_2.gif', <http.client.HTTPMessage object at 0x1104eb4a8>)
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_3.gif', <http.client.HTTPMessage object at 0x1104eb0f0>)
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_4.gif', <http.client.HTTPMessage object at 0x1104eb5f8>)
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_5.gif', <http.client.HTTPMessage object at 0x1104ebef0>)
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_6.gif', <http.client.HTTPMessage object at 0x1104eb358>)
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_7.gif', <http.client.HTTPMessage object at 0x1104eb320>)
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_8.gif', <http.client.HTTPMessage object at 0x1104eb828>)
# ('/Users/cindy/Downloads/uy2/data_vinyasa/vinyasa_9.gif', <http.client.HTTPMessage object at 0x1104ebf28>)
# ...
